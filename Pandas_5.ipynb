# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"C:\Users\Admin\Downloads\HousePrice.csv")

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %% [markdown]
# ### Q.1) find the owner's data those are having under 50 lac with rera approved.

# %%
data1=dataset.loc[(dataset["POSTED_BY"]=="Owner") & (dataset["RERA"]==1) & (dataset["TARGET(PRICE_IN_LACS)"]<50.0)]

# %%
data1
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 9         Owner                   0     1        2       BHK   879.120879
# 122       Owner                   1     1        2       BHK  1109.165207
# 128       Owner                   0     1        2       BHK   398.262129
# 282       Owner                   0     1        2       BHK   945.179584
# 321       Owner                   0     1        2       BHK  1200.417537
# ...         ...                 ...   ...      ...       ...          ...
# 29340     Owner                   0     1        2       BHK  1000.000000
# 29360     Owner                   1     1        2       BHK  1090.159104
# 29377     Owner                   0     1        2       BHK   953.389831
# 29407     Owner                   0     1        3       BHK  1463.679075
# 29416     Owner                   0     1        1       BHK   550.055005
#
#        READY_TO_MOVE  RESALE                        ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# ### Q.2) Find the count of rera approved plot the data on seaborn.

# %%
import seaborn as sns

# %%
sns.countplot(x="POSTED_BY",data=dataset)
# Out:
# <AxesSubplot:xlabel='POSTED_BY', ylabel='count'>

# %% [markdown]
# ### Q.3) How to reduce two precision in SQUARE_FT .

# %%
dataset["SQUARE_FT"].round(2)
# Out:
# 0        1300.24
# 1        1275.00
# 2         933.16
# 3         929.92
# 4         999.01
#           ...
# 29446    2500.00
# 29447     769.23
# 29448    1022.64
# 29449     927.08
# 29450     896.77
# Name: SQUARE_FT, Length: 29451, dtype: float64

# %% [markdown]
# ###  Q.4) Slice the cities also banglore data.find how many bangalore cities flats are rera approved.
