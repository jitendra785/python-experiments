# %% [markdown]
# ### Pandas 4 Working With String Slicing

# %%
import pandas as df
import numpy as np

# %%
dataset=df.read_csv(r"C:\Users\Admin\Downloads\HousePrice.csv")
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset["POSTED_BY"].replace("Owner",0,inplace=True)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0             0                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2             0                   0     0        2       BHK   933.159722
# 3             0                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446         0                   0     0        3       BHK  2500.000000
# 29447         0                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449         0                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset["POSTED_BY"].replace("Dealer",1)          # if we inplace=True is not put in replce function
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 29446    0
# 29447    0
# 29448    1
# 29449    0
# 29450    1
# Name: POSTED_BY, Length: 29451, dtype: object

# %%
dataset["POSTED_BY"].replace("Builder",2,inplace=True)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0             0                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2             0                   0     0        2       BHK   933.159722
# 3             0                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446         0                   0     0        3       BHK  2500.000000
# 29447         0                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449         0                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset["POSTED_BY"].replace("Dealer",1,inplace=True)

# %%
dataset
# Out:
#        POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0              0                   0     0        2       BHK  1300.236407
# 1              1                   0     0        2       BHK  1275.000000
# 2              0                   0     0        2       BHK   933.159722
# 3              0                   0     1        2       BHK   929.921143
# 4              1                   1     0        2       BHK   999.009247
# ...          ...                 ...   ...      ...       ...          ...
# 29446          0                   0     0        3       BHK  2500.000000
# 29447          0                   0     0        2       BHK   769.230769
# 29448          1                   0     0        2       BHK  1022.641509
# 29449          0                   0     0        2       BHK   927.079009
# 29450          1                   0     1        2       BHK   896.774194
#
# ...

# %%
dataset["POSTED_BY"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  int64
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   ADDRESS                29451 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 2.7+ MB

# %%
dataset["POSTED_BY"].replace(1,"Dealer",inplace=True)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0             0                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2             0                   0     0        2       BHK   933.159722
# 3             0                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446         0                   0     0        3       BHK  2500.000000
# 29447         0                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449         0                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset["POSTED_BY"].replace("Dealer","Dealer_Person",inplace=True)

# %%
dataset
# Out:
#            POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0                  0                   0     0        2       BHK
# 1      Dealer_Person                   0     0        2       BHK
# 2                  0                   0     0        2       BHK
# 3                  0                   0     1        2       BHK
# 4      Dealer_Person                   1     0        2       BHK
# ...              ...                 ...   ...      ...       ...
# 29446              0                   0     0        3       BHK
# 29447              0                   0     0        2       BHK
# 29448  Dealer_Person                   0     0        2       BHK
# 29449              0                   0     0        2       BHK
# 29450  Dealer_Person                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE                            ADDRESS  \
# 0      1300.236407              1       1              Ksfc Layout,Bangalore
# ...

# %%
dataset["POSTED_BY"].str.replace("Dealer_Person","Dealer")
# Out:
# 0           NaN
# 1        Dealer
# 2           NaN
# 3           NaN
# 4        Dealer
#           ...
# 29446       NaN
# 29447       NaN
# 29448    Dealer
# 29449       NaN
# 29450    Dealer
# Name: POSTED_BY, Length: 29451, dtype: object

# %%
dataset
# Out:
#            POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0                  0                   0     0        2       BHK
# 1      Dealer_Person                   0     0        2       BHK
# 2                  0                   0     0        2       BHK
# 3                  0                   0     1        2       BHK
# 4      Dealer_Person                   1     0        2       BHK
# ...              ...                 ...   ...      ...       ...
# 29446              0                   0     0        3       BHK
# 29447              0                   0     0        2       BHK
# 29448  Dealer_Person                   0     0        2       BHK
# 29449              0                   0     0        2       BHK
# 29450  Dealer_Person                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE                            ADDRESS  \
# 0      1300.236407              1       1              Ksfc Layout,Bangalore
# ...

# %%
a=input("Enter the current name:")             # replace the value from user input
b=input("Enter the replace name:")
dataset["POSTED_BY"]=dataset["POSTED_BY"].str.replace(a,b)
dataset
# Out:
# Enter the current name:Dealer_Person
# Enter the replace name:Dealer
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0           NaN                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2           NaN                   0     0        2       BHK   933.159722
# 3           NaN                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446       NaN                   0     0        3       BHK  2500.000000
# 29447       NaN                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449       NaN                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
# ...

# %%
np.round(dataset["SQUARE_FT"],3)
# Out:
# 0        1300.236
# 1        1275.000
# 2         933.160
# 3         929.921
# 4         999.009
#            ...
# 29446    2500.000
# 29447     769.231
# 29448    1022.642
# 29449     927.079
# 29450     896.774
# Name: SQUARE_FT, Length: 29451, dtype: float64

# %%
np.round(dataset["SQUARE_FT"],1)
# Out:
# 0        1300.2
# 1        1275.0
# 2         933.2
# 3         929.9
# 4         999.0
#           ...
# 29446    2500.0
# 29447     769.2
# 29448    1022.6
# 29449     927.1
# 29450     896.8
# Name: SQUARE_FT, Length: 29451, dtype: float64

# %%
dataset["SQUARE_FT"]=np.round(dataset["SQUARE_FT"],1)

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  SQUARE_FT  \
# 0           NaN                   0     0        2       BHK     1300.2
# 1        Dealer                   0     0        2       BHK     1275.0
# 2           NaN                   0     0        2       BHK      933.2
# 3           NaN                   0     1        2       BHK      929.9
# 4        Dealer                   1     0        2       BHK      999.0
# ...         ...                 ...   ...      ...       ...        ...
# 29446       NaN                   0     0        3       BHK     2500.0
# 29447       NaN                   0     0        2       BHK      769.2
# 29448    Dealer                   0     0        2       BHK     1022.6
# 29449       NaN                   0     0        2       BHK      927.1
# 29450    Dealer                   0     1        2       BHK      896.8
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset=df.read_csv(r"C:\Users\Admin\Downloads\HousePrice.csv")
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
List=[]
for x in dataset["POSTED_BY"]:
    if x=="Owner":
        List.append(0)
    elif x=="Dealer":
        List.append(1)
    else:
        List.append(2)

# %%
dataset.insert(1,"New_P_B",List)     # which gives you to add column as per required
dataset["New1_P_B"]=List             # which gives ypu to add column to particular place.

# %%
dataset
# Out:
#       POSTED_BY  New_P_B  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0         Owner        0                   0     0        2       BHK
# 1        Dealer        1                   0     0        2       BHK
# 2         Owner        0                   0     0        2       BHK
# 3         Owner        0                   0     1        2       BHK
# 4        Dealer        1                   1     0        2       BHK
# ...         ...      ...                 ...   ...      ...       ...
# 29446     Owner        0                   0     0        3       BHK
# 29447     Owner        0                   0     0        2       BHK
# 29448    Dealer        1                   0     0        2       BHK
# 29449     Owner        0                   0     0        2       BHK
# 29450    Dealer        1                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE                            ADDRESS  \
# ...

# %%
del dataset["New1_P_B"]

# %%
dataset=dataset.drop('LATITUDE',1)     # which is used to remove whole columns
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_568\3628122750.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dataset=dataset.drop('LATITUDE',1)

# %%
dataset
# Out:
#       POSTED_BY  New_P_B  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0         Owner        0                   0     0        2       BHK
# 1        Dealer        1                   0     0        2       BHK
# 2         Owner        0                   0     0        2       BHK
# 3         Owner        0                   0     1        2       BHK
# 4        Dealer        1                   1     0        2       BHK
# ...         ...      ...                 ...   ...      ...       ...
# 29446     Owner        0                   0     0        3       BHK
# 29447     Owner        0                   0     0        2       BHK
# 29448    Dealer        1                   0     0        2       BHK
# 29449     Owner        0                   0     0        2       BHK
# 29450    Dealer        1                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE                            ADDRESS  \
# ...
