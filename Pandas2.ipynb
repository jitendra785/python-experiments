# %%
import pandas as pd
import numpy as np
data=pd.read_csv(r"C:\Users\Admin\Downloads\Houseprice_by_City.csv")
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
data["POSTED_BY"].value_counts()
# Out:
# Dealer     18291
# Owner      10538
# Builder      622
# Name: POSTED_BY, dtype: int64

# %% [markdown]
# # Working With Data in pandas

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   City                   29442 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
# For loop is use to feature Transformations and also kwon as columns transformations
ab=[]

for x in data["POSTED_BY"]:
    if x=="Dealer":
        ab.append(1)
    elif x=="Owner":
        ab.append(2)
    elif x=="Builder":
        ab.append(3)

# %%
#data["NEW_POSTED_BY"]=ab

# %%
data.insert(0,"NEW_POSTED_BY",ab)

# %%
new_data=pd.DataFrame(data)

# %%
new_data
# Out:
#        NEW_POSTED_BY POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0                  2     Owner                   0     0        2       BHK
# 1                  1    Dealer                   0     0        2       BHK
# 2                  2     Owner                   0     0        2       BHK
# 3                  2     Owner                   0     1        2       BHK
# 4                  1    Dealer                   1     0        2       BHK
# ...              ...       ...                 ...   ...      ...       ...
# 29446              2     Owner                   0     0        3       BHK
# 29447              2     Owner                   0     0        2       BHK
# 29448              1    Dealer                   0     0        2       BHK
# 29449              2     Owner                   0     0        2       BHK
# 29450              1    Dealer                   0     1        2       BHK
#
# ...

# %%
del new_data["POSTED_BY"]

# %%
df=pd.DataFrame(new_data)

# %%
df
# Out:
#        NEW_POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0                  2                   0     0        2       BHK
# 1                  1                   0     0        2       BHK
# 2                  2                   0     0        2       BHK
# 3                  2                   0     1        2       BHK
# 4                  1                   1     0        2       BHK
# ...              ...                 ...   ...      ...       ...
# 29446              2                   0     0        3       BHK
# 29447              2                   0     0        2       BHK
# 29448              1                   0     0        2       BHK
# 29449              2                   0     0        2       BHK
# 29450              1                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE                  City  LONGITUDE  \
# 0      1300.236407              1       1             Bangalore  12.969910
# ...

# %%
df["NEW_POSTED_BY"].value_counts()     # above all code is to feature transformation or column Transformation.
# Out:
# 1    18291
# 2    10538
# 3      622
# Name: NEW_POSTED_BY, dtype: int64

# %%
data=df.loc[(df["City"]=="Bangalore") & (df["BHK_OR_RK"]=="RK")]

# %%
data             # here empty dataset becoz RK in banglor is not available
# Out:
# Empty DataFrame
# Columns: [NEW_POSTED_BY, UNDER_CONSTRUCTION, RERA, BHK_NO., BHK_OR_RK, SQUARE_FT, READY_TO_MOVE, RESALE, City, LONGITUDE, LATITUDE, TARGET(PRICE_IN_LACS)]
# Index: []

# %%
df["BHK_OR_RK"].value_counts()
# Out:
# BHK    29427
# RK        24
# Name: BHK_OR_RK, dtype: int64

# %%
data1=df.loc[(df["BHK_OR_RK"]=="RK")]

# %%
data1
# Out:
#        NEW_POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK   SQUARE_FT  \
# 47                 1                   0     0        1        RK  475.010326
# 2373               1                   0     0        1        RK  350.009052
# 2685               1                   1     0        1        RK  400.000000
# 5623               2                   0     0        1        RK  375.006335
# 8455               1                   0     0        1        RK  450.045005
# 9156               1                   1     0        1        RK  196.942082
# 11853              1                   0     0        1        RK  350.008077
# 13666              1                   1     1        1        RK  440.000000
# 14124              1                   1     1        1        RK  449.982693
# 14400              1                   0     0        1        RK  360.023041
# 14774              1                   1     1        1        RK  202.836663
# ...

# %%
df.isnull().any()       # checking null values in dataset is present or not
# Out:
# NEW_POSTED_BY            False
# UNDER_CONSTRUCTION       False
# RERA                     False
# BHK_NO.                  False
# BHK_OR_RK                False
# SQUARE_FT                False
# READY_TO_MOVE            False
# RESALE                   False
# City                      True
# LONGITUDE                False
# LATITUDE                 False
# TARGET(PRICE_IN_LACS)    False
# dtype: bool

# %%
df.isnull().sum()       # checking number of null values in dataset
# Out:
# NEW_POSTED_BY            0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# City                     9
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
df["City"].fillna("Lalitpur",inplace=True)      # fill specific value into specific columns

# %%
df
# Out:
#        NEW_POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0                  2                   0     0        2       BHK
# 1                  1                   0     0        2       BHK
# 2                  2                   0     0        2       BHK
# 3                  2                   0     1        2       BHK
# 4                  1                   1     0        2       BHK
# ...              ...                 ...   ...      ...       ...
# 29446              2                   0     0        3       BHK
# 29447              2                   0     0        2       BHK
# 29448              1                   0     0        2       BHK
# 29449              2                   0     0        2       BHK
# 29450              1                   0     1        2       BHK
#
#          SQUARE_FT  READY_TO_MOVE  RESALE                  City  LONGITUDE  \
# 0      1300.236407              1       1             Bangalore  12.969910
# ...

# %%
df.isnull().any()
# Out:
# NEW_POSTED_BY            False
# UNDER_CONSTRUCTION       False
# RERA                     False
# BHK_NO.                  False
# BHK_OR_RK                False
# SQUARE_FT                False
# READY_TO_MOVE            False
# RESALE                   False
# City                     False
# LONGITUDE                False
# LATITUDE                 False
# TARGET(PRICE_IN_LACS)    False
# dtype: bool
