# %% [markdown]
# # Work with pandas

# %%
import pandas as pd
import numpy as np

# %%
dict={
    "id":[1,2,3,4,5],
    "Name":["Sagar","Jitu","Ravi","Vijay","Shashi"],
    "City":["Vavade","Hol","Mandal","Shahapur","Shashikant"],
    "Salary":[10000,5500,4500,6500,8000]
}
print(dict)
# Out:
# {'id': [1, 2, 3, 4, 5], 'Name': ['Sagar', 'Jitu', 'Ravi', 'Vijay', 'Shashi'], 'City': ['Vavade', 'Hol', 'Mandal', 'Shahapur', 'Shashikant'], 'Salary': [10000, 5500, 4500, 6500, 8000]}

# %%
data=pd.DataFrame(dict)
#data.to_csv("Student_information.csv",index=False)
#df=pd.read_csv("Student_information.csv")
#df
data
# Out:
#    id    Name        City  Salary
# 0   1   Sagar      Vavade   10000
# 1   2    Jitu         Hol    5500
# 2   3    Ravi      Mandal    4500
# 3   4   Vijay    Shahapur    6500
# 4   5  Shashi  Shashikant    8000

# %%
data=pd.DataFrame(dict)
data.to_csv("Student_information.csv",index=False)
df=pd.read_csv("Student_information.csv")
df
data
# Out:
#    id    Name        City  Salary
# 0   1   Sagar      Vavade   10000
# 1   2    Jitu         Hol    5500
# 2   3    Ravi      Mandal    4500
# 3   4   Vijay    Shahapur    6500
# 4   5  Shashi  Shashikant    8000

# %%
data=pd.read_csv(r"C:\Users\Admin\Downloads\Houseprice_by_City.csv")
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
data.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# 2              1       1  Bangalore  12.778033  77.632191
# 3              1       1  Ghaziabad  28.642300  77.344500
# 4              0       1    Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# 2                   43.0
# 3                   62.5
# 4                   60.5

# %%
data.head(10)
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
# 5     Owner                   0     0        3       BHK  1250.000000
# 6    Dealer                   0     0        3       BHK  1495.053957
# 7     Owner                   0     1        3       BHK  1181.012946
# 8    Dealer                   0     1        2       BHK  1040.000000
# 9     Owner                   0     1        2       BHK   879.120879
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# ...

# %%
data.tail()
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# 29446              1       1                  Agra  27.140626  78.043277
# 29447              1       1   Lake View Recidency  39.945409 -86.150721
# 29448              1       1                Jaipur  26.928785  75.828002
# 29449              1       1               Chennai  12.900150  80.227910
# 29450              1       1                Jaipur  26.832353  75.841749
#
#        TARGET(PRICE_IN_LACS)
# 29446                   45.0
# ...

# %%
data.tail(10)
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 29441     Owner                   0     0        3       BHK  1500.375094
# 29442    Dealer                   0     0        3       BHK  1554.968123
# 29443    Dealer                   0     1        3       BHK  1161.194975
# 29444    Dealer                   1     1        1       BHK   752.049334
# 29445     Owner                   0     0        2       BHK  1062.134891
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# 29441              1       1             Faridabad  28.320000  77.289381
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   City                   29442 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
data["City"]
# Out:
# 0                   Bangalore
# 1                      Mysore
# 2                   Bangalore
# 3                   Ghaziabad
# 4                     Kolkata
#                  ...
# 29446                    Agra
# 29447     Lake View Recidency
# 29448                  Jaipur
# 29449                 Chennai
# 29450                  Jaipur
# Name: City, Length: 29451, dtype: object

# %%
data["City"].value_counts()
# Out:
# Bangalore               4319
# Lalitpur                2987
# Mumbai                  2020
# Pune                    1984
# Noida                   1765
#                         ...
#  ELECTRICITY COLONY        1
# Chhindwara                 1
# Jivarajpark                1
# opp To Nagarjuna Sch       1
#  Lake View Recidency       1
# Name: City, Length: 432, dtype: int64

# %%
data.iloc[0:10,:]
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
# 5     Owner                   0     0        3       BHK  1250.000000
# 6    Dealer                   0     0        3       BHK  1495.053957
# 7     Owner                   0     1        3       BHK  1181.012946
# 8    Dealer                   0     1        2       BHK  1040.000000
# 9     Owner                   0     1        2       BHK   879.120879
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# ...

# %%
data.iloc[0:15,2:9]
# Out:
#     RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  READY_TO_MOVE  RESALE       City
# 0      0        2       BHK  1300.236407              1       1  Bangalore
# 1      0        2       BHK  1275.000000              1       1     Mysore
# 2      0        2       BHK   933.159722              1       1  Bangalore
# 3      1        2       BHK   929.921143              1       1  Ghaziabad
# 4      0        2       BHK   999.009247              0       1    Kolkata
# 5      0        3       BHK  1250.000000              1       1      Kochi
# 6      0        3       BHK  1495.053957              1       1     Jaipur
# 7      1        3       BHK  1181.012946              1       1     Mohali
# 8      1        2       BHK  1040.000000              1       1  Bangalore
# 9      1        2       BHK   879.120879              1       1    Chennai
# 10     0        3       BHK  1350.308642              1       1   Siliguri
# ...

# %%
data.iloc[:10,[0,8]]
# Out:
#   POSTED_BY       City
# 0     Owner  Bangalore
# 1    Dealer     Mysore
# 2     Owner  Bangalore
# 3     Owner  Ghaziabad
# 4    Dealer    Kolkata
# 5     Owner      Kochi
# 6    Dealer     Jaipur
# 7     Owner     Mohali
# 8    Dealer  Bangalore
# 9     Owner    Chennai

# %%
data["City"]=="Bangalore"
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 29446    False
# 29447    False
# 29448    False
# 29449    False
# 29450    False
# Name: City, Length: 29451, dtype: bool

# %%
data["POSTED_BY"].unique()
# Out:
# array(['Owner', 'Dealer', 'Builder'], dtype=object)

# %%
data["POSTED_BY"].nunique()
# Out:
# 3

# %%
data["POSTED_BY"].value_counts()
# Out:
# Dealer     18291
# Owner      10538
# Builder      622
# Name: POSTED_BY, dtype: int64

# %%
data.shape
# Out:
# (29451, 12)

# %%
data1=data.loc[data["City"]=="Mysore"]
print(data1)
data1.shape
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 1        Dealer                   0     0        2       BHK  1275.000000
# 594       Owner                   0     0        3       BHK  1655.878368
# 690      Dealer                   0     0        2       BHK  1363.109049
# 1020     Dealer                   0     0        3       BHK  1355.199135
# 1040    Builder                   0     0        2       BHK  1179.813594
# 1337      Owner                   0     0        2       BHK  1243.915630
# 1408     Dealer                   0     0        3       BHK  1459.427904
# 1820     Dealer                   0     0        3       BHK  1351.019406
# 4485      Owner                   0     0        3       BHK  1500.000000
# 5188      Owner                   0     0        1       BHK   552.074008
# 6256      Owner                   1     0        2       BHK   855.066268
# 7879     Dealer                   0     1        2       BHK  1200.000000
# ...

# %%
import pandas as pd
import numpy as np

data=pd.read_csv(r"C:\Users\Admin\Downloads\Houseprice_by_City.csv")
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
data1=data.loc[(data["City"]=="Ghaziabad")|(data["POSTED_BY"]=="Dealer")]
data1
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 1        Dealer                   0     0        2       BHK  1275.000000
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# 6        Dealer                   0     0        3       BHK  1495.053957
# 8        Dealer                   0     1        2       BHK  1040.000000
# ...         ...                 ...   ...      ...       ...          ...
# 29442    Dealer                   0     0        3       BHK  1554.968123
# 29443    Dealer                   0     1        3       BHK  1161.194975
# 29444    Dealer                   1     1        1       BHK   752.049334
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE         City  LONGITUDE   LATITUDE  \
# ...

# %%
data2=data.loc[(data["City"]=="Ghaziabad")&(data["POSTED_BY"]=="Dealer")]
data2
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 88       Dealer                   0     1        2       BHK   996.797438
# 132      Dealer                   0     1        3       BHK  1536.806516
# 144      Dealer                   0     1        3       BHK  1400.241838
# 196      Dealer                   0     0        3       BHK  1575.157516
# 210      Dealer                   0     0        3       BHK  1395.032324
# ...         ...                 ...   ...      ...       ...          ...
# 29097    Dealer                   0     1        2       BHK  1094.845990
# 29271    Dealer                   0     1        2       BHK  1170.242407
# 29300    Dealer                   0     0        3       BHK  1275.020565
# 29346    Dealer                   0     1        3       BHK  1235.003529
# 29399    Dealer                   0     1        3       BHK  1850.149391
#
#        READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# ...

# %%
data.isnull().any()
# Out:
# POSTED_BY                False
# UNDER_CONSTRUCTION       False
# RERA                     False
# BHK_NO.                  False
# BHK_OR_RK                False
# SQUARE_FT                False
# READY_TO_MOVE            False
# RESALE                   False
# City                      True
# LONGITUDE                False
# LATITUDE                 False
# TARGET(PRICE_IN_LACS)    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# City                     9
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64
